# %% [markdown]
# <a href="https://colab.research.google.com/github/alfianaxikka-ops/alfiana-Xl.1/blob/main/1_Fungsi_print_Alfiana_Xl_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("halo dunia")
# Out:
# halo dunia

# %%
print("selamat datang di python")
# Out:
# selamat datang di python

# %%
print("Alfiana Ni'matul Ulya")
# Out:
# Alfiana Ni'matul Ulya

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
BB = 50
print(BB)
# Out:
# 50

# %%
UMUR = 16
print(UMUR)
# Out:
# 16

# %%
nama = "Alfiana Ni'matul Ulya"
print(nama)
# Out:
# Alfiana Ni'matul Ulya

# %% [markdown]
# # Menampilkan Variabel dan Teks Benas

# %%
print(f"umur saya {UMUR} tahun")
# Out:
# umur saya 16 tahun

# %%
print("halo " + nama)
# Out:
# halo Alfiana Ni'matul Ulya

# %% [markdown]
# #Menampilkan Teks Bebas dan Variabel

# %%
harga_telur = 26000
print("Harga telur per 1 kg adalah", harga_telur)
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000
print("Harga telur per 1 kg adalah " + str(harga_telur))
# Out:
# Harga telur per 1 kg adalah 26000

# %%
nama_pembeli = "Alfiana"
print("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Alfiana

# %% [markdown]
# Latihan soal
#
# 1.Tampilkan teks bebas: Hari ini saya bahagia belajar bahasa python
# 2.Tampilkan nilai variabel: mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3.Tampilkan nilai variabel: nilai_kka = 100
# 4.Tampilkan teks bebas dan nilai variabel tiga mode (f string, "+", ","): Nilai KKA saya adalah {nilai_kka}loh!"

# %%
print("Hari ini saya bahagia belajar python")
# Out:
# Hari ini saya bahagia belajar python

# %%
mata_pelajaran_favorit = "Kode dan Kecerdasan Buatan"
print(mata_pelajaran_favorit)
# Out:
# Kode dan Kecerdasan Buatan

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
print(f"Nilai KKA saya adalah {nilai_kka} loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
print("Nilai KKA saya adalah " + str(nilai_kka) + " loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
print("Nilai KKA saya adalah ", nilai_kka, "loh!")
# Out:
# Nilai KKA saya adalah  100 loh!

# %% [markdown]
# #Escape Chatacter

# %%
print("Nama: Alfiana Ni'matul Ulya")
print("Kelas: Xl.1")
print("Nomor Absen: 03")
# Out:
# Nama: Alfiana Ni'matul Ulya
# Kelas: Xl.1
# Nomor Absen: 03

# %%
print("Nama\t\t: Alfiana Ni'matul Ulya\nKelas\t\t: Xl.1\nNomor Absen\t: 03")
# Out:
# Nama		: Alfiana Ni'matul Ulya
# Kelas		: Xl.1
# Nomor Absen	: 03

# %%
print("""Nama: Alfiana Ni'matul Ulya
Kelas: Xl.1
Nomor Absen: 03""")
# Out:
# Nama: Alfiana Ni'matul Ulya
# Kelas: Xl.1
# Nomor Absen: 03

# %%
print('ja\'far shodiq')
# Out:
# ja'far shodiq

# %%
print("ja\'far shodiq")
# Out:
# ja'far shodiq

# %%
print("Bu Shinta berkata, \"Semua harus menyimak pelajaran.\"")
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print('Bu Shinta berkata, "Semua harus menyimak pelajaran."')
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print("Lokasi file video karnaval ada di D:\Karnaval 2025\mp4")
# Out:
# Lokasi file video karnaval ada di D:\Karnaval 2025\mp4
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# /tmp/ipython-input-2952592184.py:1: SyntaxWarning: invalid escape sequence '\K'
#   print("Lokasi file video karnaval ada di D:\Karnaval 2025\mp4")

# %% [markdown]
# #Parameter Fungsi Print

# %%
Tahun = 2010
Bulan = "Maret"
Tanggal = 11

print(Tanggal, end=" ")
print(Bulan, end=" ")
print(Tahun, end=" ")
# Out:
# 11 Maret 2010

# %%
Tahun = 2010
Bulan = "Maret"
Tanggal = 11

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 11/Maret/2010

# %% [markdown]
# Latihan:
#
# Tangga-Bulan-Tahun

# %%
Nama_depan = "Alfiana"
Nama_belakang = "Ni'matul Ulya"

print(Nama_depan, Nama_belakang)
# Out:
# Alfiana Ni'matul Ulya

# %%
Nama_depan = "Alfiana"
Nama_belakang = "Ni'matul Ulya"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# Alfiana Ni'matul Ulya

# %% [markdown]
# # Tugas Jadwal Pelajaran

# %%
print('Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa Rabu silahkan disimpan di laptop masing-masing di folder local disck D:\jadwal pelajaran\Kelas Xl semester 1."')

print("\njadwal pelajaran Mingguan")
print("===========================================")
print("jam\tSenin\t\tSelasa\t\tRabu")
print("jam 1\tMatematika\tBahasa\t\tInformatika")
print("jam 2\tBahasa Ingg.\tSejarah\t\tMa'rifatullah")
print("jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa Rabu silahkan disimpan di laptop masing-masing di folder local disck D:\jadwal pelajaran\Kelas Xl semester 1."
#
# jadwal pelajaran Mingguan
# ===========================================
# jam	Senin		Selasa		Rabu
# jam 1	Matematika	Bahasa		Informatika
# jam 2	Bahasa Ingg.	Sejarah		Ma'rifatullah
# jam 3	Informatika	Olahraga	Biologi
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# /tmp/ipython-input-2577223173.py:1: SyntaxWarning: invalid escape sequence '\j'
#   print('Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa Rabu silahkan disimpan di laptop masing-masing di folder local disck D:\jadwal pelajaran\Kelas Xl semester 1."')

# %%
nama_siswa_1 = "Naufal"
nama_siswa_2 = "Favian"
nama_siswa_3 = "Humaira"
nama_siswa_4 = "Favian"

print(nama_siswa_1, nama_siswa_2, nama_siswa_3, nama_siswa_4, sep="~")
# Out:
# Naufal~Favian~Humaira~Favian

# %%
nama_siswa_1 = "Naufal"
nama_siswa_2 = "Favian"
nama_siswa_3 = "Humaira"
nama_siswa_4 = "Favian"

print(nama_siswa_1, end="~")
print(nama_siswa_2 )
print(nama_siswa_3, end="~")
print(nama_siswa_4)
# Out:
# Naufal~Favian
# Humaira~Favian
