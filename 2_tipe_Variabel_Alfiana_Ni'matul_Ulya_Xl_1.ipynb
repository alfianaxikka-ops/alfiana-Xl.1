# %% [markdown]
# <a href="https://colab.research.google.com/github/alfianaxikka-ops/alfiana-Xl.1/blob/main/2_tipe_Variabel_Alfiana_Ni'matul_Ulya_Xl_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Alfiana Ni'matul Ulya
#
# Kelas : XI-1
#
# No.absen : 3

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "alfianaxikka@gmail.com"

print(email_user_1)
# Out:
# alfianaxikka@gmail.com

# %%
sabun_lifebuoy = 15000

print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peratiran Penulisan Variabel

# %%
# Penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
# Tidak boleh menggunakan spasi
nama siswa = "Afa"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-477784802.py", line 3
#     nama siswa = "Afa"
#          ^
# SyntaxError: invalid syntax

# %%
# Tidak boleh diawali dengan angka
1_nama_siswa = "Afa"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-165081113.py", line 2
#     1_nama_siswa = "Afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3294830867.py in <cell line: 0>()
#       1 # Penulisan variabel itu case sensitive/sensitif capslock
#       2 nama_siswa_1 = "Afa"
# ----> 3 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di Bahasa Python
prin = "Afa"

print(prin)
# Out:
# Afa

# %%
# Tidak boleh pakai kata kunci python
# Kalau error, harus disconnect dulu
# print = "Devin"
# print(print)

# %%
end = "Naufal"

print(end)
# Out:
# Naufal

# %%
# Tidak Deskriptif
_ = "Favian" # Bisa, tapi tidak jelas/tidak deskriptif

print(_)

# Seharusnya, yang deskriptif:

nama_pelanggan = "Favian"

print(nama_pelanggan)
# Out:
# Favian
# Favian

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "sada", "selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# sada
# selo

# %% [markdown]
# ## Chain Assignment

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ## Perubahan nilai variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# # Cara Penggunaan Operator

# %%
# Tanpa disimpan dalam variabel
print("5000*3")
# Out:
# 5000*3

# %%
# Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_kojek = 3

print(harga_kojek*banyak_kojek)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diberikan = 100000
uang_kembalian = uang_yang_diberikan-harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# # Jenis-jenis Operator

# %% [markdown]
# ## Operator Aritmatika

# %%
uang_shinta = 200000
uang_favian = 500000
uang_total = uang_shinta + uang_favian

print(uang_total)
# Out:
# 700000

# %%
uang_customer = 300000
total_belanja = 250000
uang_kembalian = uang_customer - total_belanja

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_kardus = banyak_botol_per_kardus*jumlah_kardus

print(total_jumlah_kardus)
# Out:
# 72

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti/jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2.857142857142857

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti//jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2

# %%
banyak_roti = 20
jumlah_tamu = 7

sisa_roti = banyak_roti%jumlah_tamu

print(sisa_roti)
# Out:
# 6

# %%
sisi_persegi = 5
luas_persegi = sisi_persegi**2

print(luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36
sisi_persegi = luas_persegi**0.5

print(sisi_persegi)
# Out:
# 6.0

# %% [markdown]
# #Tipe variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Shinta"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1,5

type(koordinat_bintang)
# Out:
# tuple

# %%
koordinat_titik = -1.5

type(koordinat_titik)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# # Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
# Tipe data masih string dan harus di convert ke integer/float
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1068325030.py in <cell line: 0>()
#       1 # Tipe data masih string dan harus di convert ke integer/float
# ----> 2 luas = panjang*lebar
#       3
#       4 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# str

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# luas persegi panjang adalah 40 cm^2

# %%
print("luas")
# Out:
# luas

# %%
input()
# Out:
# 5
# '5'

# %%
panjang = int(input("Masukkan panjang persegi (cm): "))
lebar = int(input("Masukkan lebar persegi (cm): "))

luas = panjang*lebar

print(f"Luas persegi adalah {luas} cm^2")
# Out:
# Masukkan panjang persegi (cm): 2
# Masukkan lebar persegi (cm): 3
# Luas persegi adalah 6 cm^2

# %%
panjang = int(input("Masukkan panjang balok (cm): "))
lebar = int(input("Masukkan lebar balok (cm): "))
tinggi = int(input("Masukkan tinggi balok (cm): "))

volume = panjang*lebar*tinggi

print(f"volume balok adalah {volume} cm^3")
# Out:
# Masukkan panjang balok (cm): 10
# Masukkan lebar balok (cm): 5
# Masukkan tinggi balok (cm): 4
# volume balok adalah 200 cm^3

# %%
panjang = float(input("Masukkan panjang balok (cm): "))
lebar = float(input("Masukkan lebar balok (cm): "))
tinggi = float(input("Masukkan tinggi balok (cm): "))

volume = panjang*lebar*tinggi

print(f"volume balok adalah {volume} cm^3")
# Out:
# Masukkan panjang balok (cm): 5.0
# Masukkan lebar balok (cm): 3.0
# Masukkan tinggi balok (cm): 1.0
# volume balok adalah 15.0 cm^3

# %%
tinggi_tabung = float(input("Masukkan tinggi tabung (m): "))
jari_jari_tabung = float(input("Masukkan jari jari tabung (m): "))
π = 3.14
volume = tinggi_tabung*jari_jari_tabung**2*π
print(f"volume tabung adalah {volume} m^3")
# Out:
# Masukkan tinggi tabung (m): 20.0
# Masukkan jari jari tabung (m): 10.0
# volume tabung adalah 6280.0 m^3

# %% [markdown]
# # Konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# #Operator perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8==5)
# Out:
# False

# %%
print(8==8)
# Out:
# True

# %%
print(1!=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka>kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125>=iq_min and 170>=tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa>=iq_min and tinggi_afa>=tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
berat_min = 50
umur_max = 24

tinggi_farel = 170
berat_farel = 55
umur_farel = 23

print(tinggi_farel>=tinggi_min and berat_farel>=berat_min and umur_farel<=umur_max)
# Out:
# True
